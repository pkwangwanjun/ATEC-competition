# %%
# -*- coding:utf-8 -*-
# %cd E:\竞赛\atec
import numpy as np
import pandas as pd
# Out:
# E:\竞赛\atec

# %%
data = pd.read_csv("atec_anti_fraud_train.csv")

# %%
data.shape
# Out:
# (994731, 300)

# %%
data[["label","id"]].groupby("label").size()

# %%
data.columns
# Out:
# Index(['id', 'label', 'date', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7',
#        ...
#        'f288', 'f289', 'f290', 'f291', 'f292', 'f293', 'f294', 'f295', 'f296',
#        'f297'],
#       dtype='object', length=300)

# %%
nanum = data.isna().sum()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(20, 40))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x=nanum.values, y=nanum.index)

# %%
nanum.value_counts()
# Out:
# 270515    78
# 136021    69
# 919       48
# 207585    24
# 0         21
# 273904    14
# 341661    14
# 925781    12
# 207448     6
# 286285     5
# 341887     4
# 211036     4
# 199825     1
# dtype: int64

# %%
nanum[nanum==270515].index
# Out:
# Index(['f64', 'f65', 'f66', 'f67', 'f68', 'f69', 'f70', 'f71', 'f76', 'f77',
#        'f78', 'f79', 'f80', 'f81', 'f82', 'f83', 'f84', 'f85', 'f86', 'f87',
#        'f88', 'f89', 'f90', 'f91', 'f92', 'f93', 'f94', 'f95', 'f96', 'f97',
#        'f98', 'f99', 'f100', 'f101', 'f111', 'f112', 'f113', 'f114', 'f115',
#        'f116', 'f117', 'f118', 'f119', 'f120', 'f121', 'f122', 'f123', 'f124',
#        'f125', 'f126', 'f127', 'f128', 'f129', 'f130', 'f131', 'f132', 'f133',
#        'f134', 'f135', 'f136', 'f137', 'f138', 'f139', 'f140', 'f141', 'f142',
#        'f143', 'f144', 'f145', 'f146', 'f147', 'f148', 'f149', 'f150', 'f151',
#        'f152', 'f153', 'f154'],
#       dtype='object')

# %%
for i in nanum.value_counts().index:  
    print("same na",i,":","['"+"','".join(nanum[nanum==i].index.get_values())+"']")
# Out:
# same na 270515 : ['f64','f65','f66','f67','f68','f69','f70','f71','f76','f77','f78','f79','f80','f81','f82','f83','f84','f85','f86','f87','f88','f89','f90','f91','f92','f93','f94','f95','f96','f97','f98','f99','f100','f101','f111','f112','f113','f114','f115','f116','f117','f118','f119','f120','f121','f122','f123','f124','f125','f126','f127','f128','f129','f130','f131','f132','f133','f134','f135','f136','f137','f138','f139','f140','f141','f142','f143','f144','f145','f146','f147','f148','f149','f150','f151','f152','f153','f154']
# ...

# %%
data[["label"]].groupby("label").size()
# Out:
# label
# -1      4725
#  0    977884
#  1     12122
# dtype: int64

# %%
data[["date"]].describe()
# Out:
#                date
# count  9.947310e+05
# mean   2.017098e+07
# std    6.011735e+01
# min    2.017090e+07
# 25%    2.017092e+07
# 50%    2.017101e+07
# 75%    2.017102e+07
# max    2.017110e+07

# %%
data.date.max(),data.date.min()
# Out:
# (20171105, 20170905)

# %%
date_size = data[["date"]].groupby("date").size()

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(figsize=(20, 40))

sns.set_color_codes("pastel")
sns.barplot(x=date_size.values, y=date_size.index,orient="h")

# %%
data[['f5']].describe()
# Out:
#                   f5
# count  794906.000000
# mean   100652.575330
# std      4023.235737
# min     10000.000000
# 25%    100802.000000
# 50%    100804.000000
# 75%    100806.000000
# max    150406.000000

# %%
data[['f32','f33','f34','f35']].describe()
# Out:
#                  f32            f33            f34            f35
# count  652844.000000  652844.000000  652844.000000  652844.000000
# mean        2.658120       3.347639       3.807876       4.778145
# std         6.029777       8.554205      10.613379      14.640272
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.000000       1.000000       1.000000       1.000000
# 75%         1.000000       1.000000       1.000000       1.000000
# max        31.000000      59.000000      66.000000     110.000000

# %%
data[['f28','f29','f30','f31']].describe()
# Out:
#                  f28            f29            f30            f31
# count  783695.000000  783695.000000  783695.000000  783695.000000
# mean        0.516618       0.518658       0.528893       0.529664
# std         0.520844       0.522475       0.641639       0.652183
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.000000       1.000000       1.000000       1.000000
# 75%         1.000000       1.000000       1.000000       1.000000
# max        13.000000      13.000000      25.000000      29.000000

# %%
data[['f102','f103','f104','f105','f106']].describe()
# Out:
#                 f102           f103           f104           f105  \
# count  708446.000000  708446.000000  708446.000000  708446.000000
# mean        7.050392      13.738636      24.839252      38.923389
# std        15.809246      28.202773      42.938109      57.943271
# min         1.000000       1.000000       1.000000       1.000000
# 25%         2.000000       3.000000       6.000000       9.000000
# 50%         3.000000       6.000000      12.000000      20.000000
# 75%         6.000000      13.000000      24.000000      42.000000
# max       302.000000     302.000000     363.000000     404.000000
#
#                 f106
# count  708446.000000
# mean       54.544657
# std        70.644509
# min         1.000000
# 25%        11.000000
# 50%        29.000000
# 75%        64.000000
# max       425.000000

# %%
data[['f20','f21','f22','f23','f52','f53']].describe()
# Out:
#                  f20            f21            f22            f23  \
# count  787283.000000  787283.000000  787283.000000  787283.000000
# mean       12.831719      17.225107      50.511008      66.338778
# std        13.691525      20.593240      58.000877      84.613690
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       1.000000       1.000000       1.000000
# 50%         4.000000       4.000000      11.000000      11.000000
# 75%        31.000000      34.000000     110.000000     124.000000
# max        32.000000      63.000000     177.000000     291.000000
#
#                  f52            f53
# count  787283.000000  787283.000000
# mean        0.588767       0.606525
# std         0.760457       0.812351
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         1.000000       1.000000
# 75%         1.000000       1.000000
# max        31.000000      56.000000

# %%
data[['f36','f37','f38','f39','f40','f41','f42','f43','f44','f45','f46','f47']].describe()
# Out:
#                 f36           f37           f38           f39           f40  \
# count  68950.000000  68950.000000  68950.000000  68950.000000  68950.000000
# mean       1.505859      1.633387      2.584844      3.447687      4.548368
# std        0.503352      0.602979      1.809396      3.227760      5.115391
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        1.000000      1.000000      1.000000      2.000000      2.000000
# 50%        2.000000      2.000000      2.000000      2.000000      3.000000
# 75%        2.000000      2.000000      3.000000      4.000000      5.000000
# max        3.000000      3.000000      9.000000     17.000000     32.000000
#
#                 f41           f42           f43           f44           f45  \
# count  68950.000000  68950.000000  68950.000000  68950.000000  68950.000000
# mean       2.263684      3.382335      8.456853     11.575243     14.383060
# ...

# %%
data[['f48','f49','f50','f51','f54','f55','f56','f57','f58','f59','f60','f61','f62','f63']].describe()
# Out:
#                  f48            f49            f50            f51  \
# count  653070.000000  653070.000000  653070.000000  653070.000000
# mean        2.526633       3.181717       3.629997       4.555011
# std         5.921508       8.408818      10.508260      14.495432
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.000000       1.000000       1.000000       1.000000
# 75%         1.000000       1.000000       1.000000       1.000000
# max        31.000000      59.000000      66.000000     110.000000
#
#                  f54            f55            f56            f57  \
# count  653070.000000  653070.000000  653070.000000  653070.000000
# mean        2.098623       2.682803       4.937512       6.583310
# std         2.549261       4.793870      12.498961      18.106917
# min         1.000000       1.000000       1.000000       1.000000
# ...

# %%
data[['f72','f73','f74','f75','f107','f108','f109','f110','f155','f156','f157','f158','f159','f160']].describe()
# Out:
#                  f72            f73            f74            f75  \
# count  720827.000000  720827.000000  720827.000000  720827.000000
# mean       23.847242      40.544978      23.848989      40.546295
# std        43.383086      76.756463      43.384232      76.754371
# min         0.000000       0.000000       0.000000       0.000000
# 25%         5.000000       8.000000       5.000000       8.000000
# 50%        12.000000      19.000000      12.000000      19.000000
# 75%        24.000000      42.000000      24.000000      42.000000
# max       592.000000    1480.000000     592.000000    1481.000000
#
#                 f107           f108           f109           f110  \
# count  720827.000000  720827.000000  720827.000000  720827.000000
# mean        6.963488      13.539622      24.502306      38.647040
# std        15.358109      27.235051      40.841265      55.685731
# min         1.000000       1.000000       1.000000       1.000000
# ...

# %%
# min         1.000000       1.000000       1.000000       1.000000
# ...

# %%
data[['f64','f65','f66','f67','f68','f69','f70','f71','f76','f77','f78','f79','f80','f81','f82','f83','f84','f85','f86','f87','f88','f89','f90','f91','f92','f93','f94','f95','f96','f97','f98','f99','f100','f101','f111','f112','f113','f114','f115','f116','f117','f118','f119','f120','f121','f122','f123','f124','f125','f126','f127','f128','f129','f130','f131','f132','f133','f134','f135','f136','f137','f138','f139','f140','f141','f142','f143','f144','f145','f146','f147','f148','f149','f150','f151','f152','f153','f154']].describe()
# Out:
#                  f64            f65            f66            f67  \
# count  724216.000000  724216.000000  724216.000000  724216.000000
# mean       65.034831      18.900567     157.210001     133.365518
# std        80.572275      18.913159     143.648599     141.770156
# min         1.000000       1.000000       1.000000       1.000000
# 25%         2.000000       1.000000       7.000000       2.000000
# 50%         3.000000       2.000000     133.000000      12.000000
# 75%        96.000000      38.000000     301.000000     301.000000
# max       243.000000      59.000000     430.000000     302.000000
#
#                  f68            f69            f70            f71  \
# count  724216.000000  724216.000000  724216.000000  724216.000000
# mean      147.865591     148.371515     149.745209     151.960668
# std       148.764337     148.413260     147.522766     146.279607
# min         1.000000       1.000000       1.000000       1.000000
# ...

# %%
data.id.nunique()
# Out:
# 994731

# %%
print(data.dtypes)
# Out:
# id        object
# label      int64
# date       int64
# f1         int64
# f2         int64
# f3         int64
# f4         int64
# f5       float64
# f6         int64
# f7         int64
# f8         int64
# f9         int64
# f10        int64
# f11        int64
# f12        int64
# f13        int64
# f14        int64
# f15        int64
# f16        int64
# f17        int64
# f18        int64
# f19        int64
# f20      float64
# f21      float64
# f22      float64
# f23      float64
# f24      float64
# f25      float64
# f26      float64
# f27      float64
#           ...
# f268     float64
# f269     float64
# f270     float64
# f271     float64
# f272     float64
# f273     float64
# f274     float64
# f275     float64
# f276     float64
# f277     float64
# f278     float64
# f279     float64
# f280     float64
# f281     float64
# f282     float64
# f283     float64
# f284     float64
# f285     float64
# f286     float64
# f287     float64
# f288     float64
# ...

# %%
testa = pd.read_csv("atec_anti_fraud_test_a.csv")

# %%
nanum = testa.isna().sum()

# %%
nanum.value_counts()
# Out:
# 312416    78
# 85376     69
# 1704      48
# 120906    24
# 0         20
# 313461    14
# 173136    14
# 465135    12
# 120873     6
# 318424     5
# 173471     4
# 122582     4
# 123064     1
# dtype: int64

# %%
for i in nanum.value_counts().index:  
    print("same na",i,":","['"+"','".join(nanum[nanum==i].index.get_values())+"']")
# Out:
# same na 312416 : ['f64','f65','f66','f67','f68','f69','f70','f71','f76','f77','f78','f79','f80','f81','f82','f83','f84','f85','f86','f87','f88','f89','f90','f91','f92','f93','f94','f95','f96','f97','f98','f99','f100','f101','f111','f112','f113','f114','f115','f116','f117','f118','f119','f120','f121','f122','f123','f124','f125','f126','f127','f128','f129','f130','f131','f132','f133','f134','f135','f136','f137','f138','f139','f140','f141','f142','f143','f144','f145','f146','f147','f148','f149','f150','f151','f152','f153','f154']
# ...

# %%
same na 312416 : ['f64','f65','f66','f67','f68','f69','f70','f71','f76','f77','f78','f79','f80','f81','f82','f83','f84','f85','f86','f87','f88','f89','f90','f91','f92','f93','f94','f95','f96','f97','f98','f99','f100','f101','f111','f112','f113','f114','f115','f116','f117','f118','f119','f120','f121','f122','f123','f124','f125','f126','f127','f128','f129','f130','f131','f132','f133','f134','f135','f136','f137','f138','f139','f140','f141','f142','f143','f144','f145','f146','f147','f148','f149','f150','f151','f152','f153','f154']
same na 85376 : ['f166','f167','f168','f169','f170','f171','f172','f173','f174','f175','f176','f177','f178','f179','f180','f181','f182','f183','f184','f185','f186','f187','f188','f189','f190','f191','f192','f193','f194','f195','f196','f197','f198','f199','f200','f201','f202','f203','f204','f205','f206','f207','f208','f209','f210','f254','f255','f256','f257','f258','f259','f260','f261','f262','f263','f264','f265','f266','f267','f268','f269','f270','f271','f272','f273','f274','f275','f276','f277']
